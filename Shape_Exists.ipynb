# %%
# importing set of tools and setting the workspace to the correct file location
import arcpy
arcpy.env.workspace = r"R:\GEOG491_16440_FALL2025\Student_Data\gshaffer\Week2\Lab2\Ex06"

# %%
# establishing variables
fc = "cities.shp" 
newfc = "cities_copy.shp"

# %%
# Making copy of the feature if it exists 
if arcpy.Exists(fc): 
        arcpy.CopyFeatures_management(fc, newfc)
# Out:
# ---------------------------------------------------------------------------
# ExecuteError                              Traceback (most recent call last)
# Cell In[14], line 3
#       1 # Making copy of the feature if it exists
#       2 if arcpy.Exists(fc):
# ----> 3         arcpy.CopyFeatures_management(fc, newfc)
#
# File C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\management.py:6656, in CopyFeatures(in_features, out_feature_class, config_keyword, spatial_grid_1, spatial_grid_2, spatial_grid_3)
#    6654     return retval
#    6655 except Exception as e:
# -> 6656     raise e
#
# File C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\management.py:6647, in CopyFeatures(in_features, out_feature_class, config_keyword, spatial_grid_1, spatial_grid_2, spatial_grid_3)
#    6643 from arcpy.arcobjects.arcobjectconversion import convertArcObjectToPythonObject
#    6645 try:
#    6646     retval = convertArcObjectToPythonObject(
# -> 6647         gp.CopyFeatures_management(
# ...
