# %%
# importing correct coding tools 
import arcpy
# allows for overwriting errors that may happen in case a file already exists 
arcpy.env.overwriteOutput = True
# establishig workspace and allowing for overwrite 
arcpy.env.workspace = r"R:\GEOG491_16440_FALL2025\Student_Data\gshaffer\Week2\Lab2\Ex06"

# %%
fieldlist = arcpy.ListFields("cities.shp")
for field in fieldlist: 
    print(field.name + " " + field.type)
# Out:
# FID OID
# Shape Geometry
# CITIESX020 Double
# FEATURE String
# NAME String
# POP_RANGE String
# POP_2000 Integer
# FIPS55 String
# COUNTY String
# FIPS String
# STATE String
# STATE_FIPS String
# DISPLAY SmallInteger
