# %%
# allows use of arcpy toolkit 
import arcpy
# setting correct workspace in R drive under exercise 8 
arcpy.env.workspace = r"R:\GEOG491_16440_FALL2025\Student_Data\gshaffer\Lab3\Challenge"

# shapefile for this code: 
shp = "TRANS_PLAN_ADOPTED_2006.shp"

# allowing for overwrite of the code 
arcpy.env.overwriteOutput = True

# %%
# 200 foot buffer for Major Arterials in layer field

# Expression selecting for the Major Arterials in  layer field 
# Setting the output feature for Maj_Art.shp file for the SQL expression
out_features_Maj_Art = r"R:\GEOG491_16440_FALL2025\Student_Data\gshaffer\Lab3\Challenge\Maj_Art.shp"
# setting the where clause 
where_Maj_Art = '"Layer" = \'MAJART\''

# Running the select features
Maj_Art_Select = arcpy.analysis.Select(shp, out_features_Maj_Art, where_Maj_Art)
                
# Creating the output location for te Major Arterials 
ART_Buffer_Output = r"R:\GEOG491_16440_FALL2025\Student_Data\gshaffer\Lab3\Challenge\MAJART_Buffer_Output"

# buffer variable for Major Arterials 
ART_Buffer = "200 Feet"

# %%
# 100 foot buffer for Major Collectors in layer field

# Expression selecting for the Major Arterials in  layer field 
# Setting the output feature for Maj_Art.shp file for the SQL expression
out_features_Maj_Col = r"R:\GEOG491_16440_FALL2025\Student_Data\gshaffer\Lab3\Challenge\Maj_Col.shp"
# setting the where clause 
where_Maj_Col = '"Layer" = \'MAJCOL\''

# Running the select features
Maj_Art_Select = arcpy.analysis.Select(shp, out_features_Maj_Col, where_Maj_Col)

# creating the output location 
COL_Buffer_Output = r"R:\GEOG491_16440_FALL2025\Student_Data\gshaffer\Lab3\Challenge\MAJCOL_Buffer_Output"

# buffer variable for Major Collectors 
COL_Buffer = "100 Feet"

# %%
# final buffer expressions 

# buffer expression for Major Arterials
buffer_Maj_Art = arcpy.analysis.Buffer("Maj_Art.shp", ART_Buffer_Output, ART_Buffer, "FULL", "ROUND", "ALL")

# buffer expression for Major Collectors 
buffer_Maj_Art = arcpy.analysis.Buffer("Maj_Col.shp", COL_Buffer_Output, COL_Buffer, "FULL", "ROUND", "ALL")
