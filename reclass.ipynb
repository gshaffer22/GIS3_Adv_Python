# %%
# importing arcpy 
import arcpy

from arcpy.sa import * 

arcpy.env.workspace = r"R:\GEOG491_16440_FALL2025\Student_Data\gshaffer\Lab4\Ex10"

# %%
# changing the values of these land types to a different scale
myremap = RemapValue([[41,1], [42,2], [43,3]])
# reclassifying them 
outreclass = Reclassify("landcover.tif", "VALUE", myremap, "NODATA") 
# saving the new reclassified raster
outreclass.save("lc_recl")
