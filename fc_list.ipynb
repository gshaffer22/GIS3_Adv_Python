# %%
import arcpy
arcpy.env.workspace = r"R:\GEOG491_16440_FALL2025\Student_Data\gshaffer\Week2\Lab2\Ex07"
fclist = arcpy.ListFeatureClasses()
for fc in fclist:    # added colon for correct syntax
    desc = arcpy.da.Describe(fc)    # capitalized Describe 
    print(f'{desc["baseName"]}: {desc["shapeType"]}')
# Out:
# bike_routes: Polyline
# county: Polygon
# facilities: Point
# parks: Polygon
