# %%
# getting the right set of functions 
import arcpy
# setting the correct workspace 
arcpy.env.workspace = r"R:\GEOG491_16440_FALL2025\Student_Data\gshaffer\Week2\Lab2\Ex06"
fclist = arcpy.ListFeatureClasses()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[3], line 2
#       1 # getting the right set of functions
# ----> 2 import arcpy
#       3 # setting the correct workspace
#       4 arcpy.env.workspace = r"R:\GEOG491_16440_FALL2025\Student_Data\gshaffer\Week2\Lab2\Ex06"
#
# File C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\__init__.py:77
#      74         sys.argv = ['']
#      75     import _initagsenv
# ---> 77 from arcpy.geoprocessing import gp
#      78 from arcpy.geoprocessing import env
#      79 from arcpy.geoprocessing._base import gptooldoc as _gptooldoc
#
# File C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\geoprocessing\__init__.py:14
#       1 #COPYRIGHT 2018 ESRI
#       2 #
#       3 #TRADE SECRETS: ESRI PROPRIETARY AND CONFIDENTIAL
#    (...)
#      12 #
#      13 #email: contracts@esri.com
# ---> 14 from ._base import *
#
# File C:\Program Files\ArcGIS\Pro\Resources\ArcPy\arcpy\geoprocessing\_base.py:14
#       1 #COPYRIGHT 2018 ESRI
#       2 #
#       3 #TRADE SECRETS: ESRI PROPRIETARY AND CONFIDENTIAL
#    (...)
#      12 #
#      13 #email: contracts@esri.com
# ---> 14 import arcgisscripting
#      15 from enum import Enum
#      17 """Geoprocessing wrapper for the arcgisscripting library. Attempts to organize/make usage easier."""
#
# File C:\Program Files\ArcGIS\Pro\bin\Python\envs\arcgispro-py3\Lib\site-packages\arcgisscripting\__init__.py:131
#     127 if "active_pyd_pth" in locals():del(active_pyd_pth)
#     128 if "pristine_pyd_pth" in locals():del(pristine_pyd_pth)
# --> 131 from ._arcgisscripting import *
#     132 from ._arcgisscripting import _addTimeInterval, _analyzeForSD, _attachLocator, \
#     133     _convertWebMapToMapDocument, _createGISServerConnectionFile, \
#     134     _createGeocodeSDDraft, _createMapSDDraft, _createimageservicesddraft, \
#    (...)
#     138     _setRasterKeyMetadata, _sharing, _ss, _wrapLocalFunctionRaster, \
#     139     _wrapToolRaster, _ia, _refreshLayer, _pauseDrawing, _restoreDrawing
#
# RuntimeError: The Product License has not been initialized.

# %%
for fc in fc list: 
    fcdesc = arcpy.da.Describe(fc) 
    dtype = fcdesc["dataType"]
    name = fcdesc["name"]
    stype = fcdesc["shapeType"]
    print (f"{dtype} {name} has shapetype {stype}")
